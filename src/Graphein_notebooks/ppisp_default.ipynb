# %%
# !pip install torch==2.1.0
# !pip install dgl==2.1.0
# !pip install torchdata==0.7.1
# Out:
# Requirement already satisfied: torch==2.1.0 in /opt/conda/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (3.29.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (4.15.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.11/site-packages (from torch==2.1.0) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch==2.1.0) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch==2.1.0) (1.3.0)
# Requirement already satisfied: dgl==2.1.0 in /opt/conda/lib/python3.11/site-packages (2.1.0)
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (1.17.1)
# Requirement already satisfied: networkx>=2.1 in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (3.6.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (2.34.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (4.68.3)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (5.9.5)
# Requirement already satisfied: torchdata>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from dgl==2.1.0) (0.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->dgl==2.1.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->dgl==2.1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->dgl==2.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->dgl==2.1.0) (2023.7.22)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.11/site-packages (from torchdata>=0.5.0->dgl==2.1.0) (2.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (3.29.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (4.15.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl==2.1.0) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->torchdata>=0.5.0->dgl==2.1.0) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl==2.1.0) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl==2.1.0) (1.3.0)
# Requirement already satisfied: torchdata==0.7.1 in /opt/conda/lib/python3.11/site-packages (0.7.1)
# Requirement already satisfied: urllib3>=1.25 in /opt/conda/lib/python3.11/site-packages (from torchdata==0.7.1) (2.0.7)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from torchdata==0.7.1) (2.34.2)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.11/site-packages (from torchdata==0.7.1) (2.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (3.29.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (4.15.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.11/site-packages (from torch>=2->torchdata==0.7.1) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2->torchdata==0.7.1) (12.9.86)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->torchdata==0.7.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->torchdata==0.7.1) (3.4)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.11/site-packages (from requests->torchdata==0.7.1) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=2->torchdata==0.7.1) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy->torch>=2->torchdata==0.7.1) (1.3.0)

# %%
import pickle
import pandas as pd
import numpy as np
from tqdm import tqdm

import dgl
import torch
from torch.nn import NLLLoss
from torch.utils.data import DataLoader
from Bio.PDB import *
from sklearn.metrics import f1_score, precision_score, recall_score, matthews_corrcoef

from graphein.construct_graphs import ProteinGraph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 6
#       3 import numpy as np
#       4 from tqdm import tqdm
# ----> 6 import dgl
#       7 import torch
#       8 from torch.nn import NLLLoss
#
# File /opt/conda/lib/python3.11/site-packages/dgl/__init__.py:16
#      13 from .logging import enable_verbose_logging  # usort: skip
#      14 from .backend import backend_name, load_backend  # usort: skip
# ---> 16 from . import (
#      17     container,
#      18     cuda,
#      19     dataloading,
#      20     function,
#      21     ops,
#      22     random,
#      23     sampling,
#      24     storages,
#      25 )
#      26 from ._ffi.base import __version__, DGLError
#      27 from ._ffi.function import (
#      28     extract_ext_funcs,
#      29     get_global_func,
#      30     list_global_func_names,
#      31     register_func,
#      32 )
#
# File /opt/conda/lib/python3.11/site-packages/dgl/dataloading/__init__.py:13
#      11 if F.get_preferred_backend() == "pytorch":
#      12     from .spot_target import *
# ---> 13     from .dataloader import *
#      14     from .dist_dataloader import *
#
# File /opt/conda/lib/python3.11/site-packages/dgl/dataloading/dataloader.py:27
#      25 from ..batch import batch as batch_graphs
#      26 from ..cuda import GPUCache
# ---> 27 from ..distributed import DistGraph
#      28 from ..frame import LazyFeature
#      29 from ..heterograph import DGLGraph
#
# File /opt/conda/lib/python3.11/site-packages/dgl/distributed/__init__.py:5
#       3 from .dist_context import exit_client, initialize
#       4 from .dist_dataloader import DistDataLoader
# ----> 5 from .dist_graph import DistGraph, DistGraphServer, edge_split, node_split
#       6 from .dist_tensor import DistTensor
#       7 from .graph_partition_book import GraphPartitionBook, PartitionPolicy
#
# File /opt/conda/lib/python3.11/site-packages/dgl/distributed/dist_graph.py:11
#       7 from collections.abc import MutableMapping
#       9 import numpy as np
# ---> 11 from .. import backend as F, graphbolt as gb, heterograph_index
#      12 from .._ffi.ndarray import empty_shared_mem
#      13 from ..base import ALL, DGLError, EID, ETYPE, is_all, NID
#
# File /opt/conda/lib/python3.11/site-packages/dgl/graphbolt/__init__.py:55
#      51     except Exception:  # pylint: disable=W0703
#      52         raise ImportError("Cannot load Graphbolt C++ library")
# ---> 55 load_graphbolt()
#
# File /opt/conda/lib/python3.11/site-packages/dgl/graphbolt/__init__.py:45, in load_graphbolt()
#      43 path = os.path.join(dirname, "graphbolt", basename)
#      44 if not os.path.exists(path):
# ---> 45     raise FileNotFoundError(
#      46         f"Cannot find DGL C++ graphbolt library at {path}"
#      47     )
#      49 try:
#      50     torch.classes.load_library(path)
#
# FileNotFoundError: Cannot find DGL C++ graphbolt library at /opt/conda/lib/python3.11/site-packages/dgl/graphbolt/libgraphbolt_pytorch_2.13.0.so
